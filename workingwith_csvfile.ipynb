# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("Dataset/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male   34      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female   47      1      0
# 2                       Myles, Mr. Thomas Francis    male   62      0      0
# 3                                Wirz, Mr. Albert    male   27      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22      1      1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    int32
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(1), int32(1), int64(5), object(5)
# memory usage: 37.7+ KB

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
len(df)
# Out:
# 418

# %%
df.nunique()
# Out:
# PassengerId    418
# Survived         2
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # index_comlumn

# %%
pd.read_csv("Dataset/titanic.csv",index_col="PassengerId")
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %% [markdown]
# # usecols_column

# %%
pd.read_csv("Dataset/titanic.csv",usecols=['PassengerId','Name','Age','Ticket'],index_col="PassengerId")
# Out:
#                                                      Name   Age  \
# PassengerId
# 892                                      Kelly, Mr. James  34.5
# 893                      Wilkes, Mrs. James (Ellen Needs)  47.0
# 894                             Myles, Mr. Thomas Francis  62.0
# 895                                      Wirz, Mr. Albert  27.0
# 896          Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ...                                                   ...   ...
# 1305                                   Spector, Mr. Woolf   NaN
# 1306                         Oliva y Ocana, Dona. Fermina  39.0
# 1307                         Saether, Mr. Simon Sivertsen  38.5
# 1308                                  Ware, Mr. Frederick   NaN
# 1309                             Peter, Master. Michael J   NaN
#
#                          Ticket
# PassengerId
# 892                      330911
# 893                      363272
# 894                      240276
# 895                      315154
# ...

# %% [markdown]
# # Encodeing_parameter

# %% [markdown]
# # datatype_convet parameter

# %%
pd.read_csv("Dataset/titanic.csv",dtype={'Age':np.int32}).info()
# Out:
# C:\Users\Manish\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234: RuntimeWarning: invalid value encountered in cast
#   chunks = self._reader.read_low_memory(nrows)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File parsers.pyx:1161, in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('int32') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 pd.read_csv("Dataset/titanic.csv",dtype={'Age':np.int32}).info()
#
# ...

# %%
df['Age'] = df['Age'].astype('int32')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df['Age'] = df['Age'].astype('int32')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %%
df['Age'] = df['Age'].fillna(0).astype('int32')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male   34      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female   47      1      0
# 2                       Myles, Mr. Thomas Francis    male   62      0      0
# 3                                Wirz, Mr. Albert    male   27      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22      1      1
# ...

# %% [markdown]
# # Handlingdates

# %%
pd.read_csv("Dataset/countryLockdowndates.csv")
# Out:
#          Country/Region Province        Date  Type  \
# 0           Afghanistan      NaN  24/03/2020  Full
# 1               Albania      NaN  08/03/2020  Full
# 2               Algeria      NaN  24/03/2020  Full
# 3               Andorra      NaN  16/03/2020  Full
# 4                Angola      NaN  24/03/2020  Full
# ..                  ...      ...         ...   ...
# 302           Venezuela      NaN  16/03/2020  Full
# 303             Vietnam      NaN  19/03/2020  Full
# 304  West Bank and Gaza      NaN  05/03/2020  Full
# 305              Zambia      NaN         NaN   NaN
# 306            Zimbabwe      NaN  27/03/2020  Full
#
#                                              Reference
# 0    https://www.thestatesman.com/world/afghan-govt...
# 1    https://en.wikipedia.org/wiki/2020_coronavirus...
# 2    https://www.garda.com/crisis24/news-alerts/325...
# 3    https://en.wikipedia.org/wiki/2020_coronavirus...
# 4    https://en.wikipedia.org/wiki/2020_coronavirus...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country/Region  307 non-null    object
#  1   Province        129 non-null    object
#  2   Date            230 non-null    object
#  3   Type            230 non-null    object
#  4   Reference       238 non-null    object
# dtypes: object(5)
# memory usage: 12.1+ KB

# %%
pd.read_csv("Dataset/countryLockdowndates.csv",parse_dates=['Date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country/Region  307 non-null    object
#  1   Province        129 non-null    object
#  2   Date            230 non-null    datetime64[ns]
#  3   Type            230 non-null    object
#  4   Reference       238 non-null    object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 12.1+ KB
# C:\Users\Manish\AppData\Local\Temp\ipykernel_1968\3739668503.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.read_csv("Dataset/countryLockdowndates.csv",parse_dates=['Date']).info()

# %%
# you can here check the date after parse dates convet into string into datatime64[ns] now you can acces
# the datefunction without conveting not use because date is string first time without change
