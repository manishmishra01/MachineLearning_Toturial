# %%
import pandas as pd

# %%
df=pd.read_csv("Dataset/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # head() funtion is used to show the 5 rows from upper

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # tail() its show the 5 row from the lower side from the dataset

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# # info() method is used to information about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# # value_counts() is used to how values inside the datset

# %%
df.head().value_counts
# Out:
# <bound method DataFrame.value_counts of    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S  >

# %% [markdown]
# #  Cleaning data

# %%
# check the how many row empty using this method 
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# check the total no rows is empty use this method 
df.isnull().sum().sum()
# Out:
# 414

# %%
# cleaning the data and fil the data where is empty using this two mclassmethod
#dropna()
ndf=df.dropna()

# %%
ndf
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87 entries, 12 to 414
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  87 non-null     int64
#  1   Survived     87 non-null     int64
#  2   Pclass       87 non-null     int64
#  3   Name         87 non-null     object
#  4   Sex          87 non-null     object
#  5   Age          87 non-null     float64
#  6   SibSp        87 non-null     int64
#  7   Parch        87 non-null     int64
#  8   Ticket       87 non-null     object
#  9   Fare         87 non-null     float64
#  10  Cabin        87 non-null     object
#  11  Embarked     87 non-null     object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 8.8+ KB

# %%
ndf.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# after the remove the empty values then no data is vecant 
ndf.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # so i want to use another way to handle the empty data

# %%
d1=pd.read_csv("Dataset/countryLockdowndates.csv")

# %%
d1
# Out:
#          Country/Region Province        Date  Type  \
# 0           Afghanistan      NaN  24/03/2020  Full
# 1               Albania      NaN  08/03/2020  Full
# 2               Algeria      NaN  24/03/2020  Full
# 3               Andorra      NaN  16/03/2020  Full
# 4                Angola      NaN  24/03/2020  Full
# ..                  ...      ...         ...   ...
# 302           Venezuela      NaN  16/03/2020  Full
# 303             Vietnam      NaN  19/03/2020  Full
# 304  West Bank and Gaza      NaN  05/03/2020  Full
# 305              Zambia      NaN         NaN   NaN
# 306            Zimbabwe      NaN  27/03/2020  Full
#
#                                              Reference
# 0    https://www.thestatesman.com/world/afghan-govt...
# 1    https://en.wikipedia.org/wiki/2020_coronavirus...
# 2    https://www.garda.com/crisis24/news-alerts/325...
# 3    https://en.wikipedia.org/wiki/2020_coronavirus...
# 4    https://en.wikipedia.org/wiki/2020_coronavirus...
# ...

# %%
d1.isnull().sum()
# Out:
# Country/Region      0
# Province          178
# Date               77
# Type               77
# Reference          69
# dtype: int64

# %%
# now not this time remove the cell just fill the value where is empty 
d1['Province'].fillna(0)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 302    0
# 303    0
# 304    0
# 305    0
# 306    0
# Name: Province, Length: 307, dtype: object

# %%
d1.isnull().sum()
# Out:
# Country/Region      0
# Province          178
# Date               77
# Type               77
# Reference          69
# dtype: int64

# %%
 # Replace with earliest date
d1['Type'].fillna('Unknown', inplace=True)
d1['Reference'].fillna('NoReference', inplace=True)
# Out:
# C:\Users\Manish\AppData\Local\Temp\ipykernel_19308\4158735332.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d1['Reference'].fillna('NoReference', inplace=True)

# %%
d1.isnull().sum()
# Out:
# Country/Region     0
# Province           0
# Date              77
# Type               0
# Reference          0
# dtype: int64

# %%
d1
# Out:
#          Country/Region Province        Date  Type  \
# 0           Afghanistan      NaN  24/03/2020  Full
# 1               Albania      NaN  08/03/2020  Full
# 2               Algeria      NaN  24/03/2020  Full
# 3               Andorra      NaN  16/03/2020  Full
# 4                Angola      NaN  24/03/2020  Full
# ..                  ...      ...         ...   ...
# 302           Venezuela      NaN  16/03/2020  Full
# 303             Vietnam      NaN  19/03/2020  Full
# 304  West Bank and Gaza      NaN  05/03/2020  Full
# 305              Zambia      NaN         NaN   NaN
# 306            Zimbabwe      NaN  27/03/2020  Full
#
#                                              Reference
# 0    https://www.thestatesman.com/world/afghan-govt...
# 1    https://en.wikipedia.org/wiki/2020_coronavirus...
# 2    https://www.garda.com/crisis24/news-alerts/325...
# 3    https://en.wikipedia.org/wiki/2020_coronavirus...
# 4    https://en.wikipedia.org/wiki/2020_coronavirus...
# ...

# %%
d1
# Out:
#          Country/Region     Province Date     Type  \
# 0           Afghanistan  No Province  NaT     Full
# 1               Albania  No Province  NaT     Full
# 2               Algeria  No Province  NaT     Full
# 3               Andorra  No Province  NaT     Full
# 4                Angola  No Province  NaT     Full
# ..                  ...          ...  ...      ...
# 302           Venezuela  No Province  NaT     Full
# 303             Vietnam  No Province  NaT     Full
# 304  West Bank and Gaza  No Province  NaT     Full
# 305              Zambia  No Province  NaT  Unknown
# 306            Zimbabwe  No Province  NaT     Full
#
#                                              Reference
# 0    https://www.thestatesman.com/world/afghan-govt...
# 1    https://en.wikipedia.org/wiki/2020_coronavirus...
# 2    https://www.garda.com/crisis24/news-alerts/325...
# 3    https://en.wikipedia.org/wiki/2020_coronavirus...
# 4    https://en.wikipedia.org/wiki/2020_coronavirus...
# ...

# %% [markdown]
# # duplicated_value

# %%
d1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # correlation between two variable

# %% [markdown]
# # ploting in pandas

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.plot()
plt.show()

# %%
df.plot(kind = 'scatter', x = 'Fare', y = 'Survived')
plt.show()

# %%
df.plot(x = 'Pclass', y = 'Survived')
plt.show()
